# %% [markdown]
# # Importing the necessary library

# %%
import pandas as pd
import sklearn

# %% [markdown]
# ### Load the dataset

# %%
movies_df = pd.read_csv("Hydra-Movie-Scrape.csv")

# %%
# visulaize the dataset
movies_df.head()
# Out:
#                                                Title  Year  \
# 0                        Patton Oswalt: Annihilation  2017
# 1                                      New York Doll  2005
# 2  Mickey's Magical Christmas: Snowed in at the H...  2001
# 3                         Mickey's House of Villains  2001
# 4                                      And Then I Go  2017
#
#                                              Summary  \
# 0  Patton Oswald, despite a personal tragedy, pro...
# 1  A recovering alcoholic and recently converted ...
# 2  After everyone is snowed in at the House of Mo...
# 3  The villains from the popular animated Disney ...
# 4  In the cruel world of junior high, Edwin suffe...
#
#                                        Short Summary  \
# 0  Patton Oswalt, despite a personal tragedy, pro...
# 1  A recovering alcoholic and recently converted ...
# 2  Mickey and all his friends hold their own Chri...
# 3  The villains from the popular animated Disney ...
# ...

# %%
# removing column that are not very useful
movies_df = movies_df.drop(['IMDB ID', 'Runtime','YouTube Trailer','Summary'], axis=1)

# %%
# checking for the current state of the dataset
movies_df.head()
# Out:
#                                                Title  Year  \
# 0                        Patton Oswalt: Annihilation  2017
# 1                                      New York Doll  2005
# 2  Mickey's Magical Christmas: Snowed in at the H...  2001
# 3                         Mickey's House of Villains  2001
# 4                                      And Then I Go  2017
#
#                                        Short Summary  \
# 0  Patton Oswalt, despite a personal tragedy, pro...
# 1  A recovering alcoholic and recently converted ...
# 2  Mickey and all his friends hold their own Chri...
# 3  The villains from the popular animated Disney ...
# 4  In the cruel world of junior high, Edwin suffe...
#
#                                       Genres  Rating  \
# 0                              Uncategorized     7.4
# 1                          Documentary|Music     7.9
# 2  Adventure|Animation|Comedy|Family|Fantasy     6.8
# 3     Animation|Comedy|Family|Fantasy|Horror     6.6
# ...

# %%
movies_df.describe()
# Out:
#               Year       Rating
# count  3940.000000  3940.000000
# mean   2012.132741     6.555685
# std       4.821189     0.892572
# min    2000.000000     1.700000
# 25%    2009.000000     6.100000
# 50%    2013.000000     6.600000
# 75%    2016.000000     7.100000
# max    2018.000000     9.500000

# %%
movies_df.shape[1]
# Out:
# 9

# %%
#checking for null values
movies_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3940 entries, 0 to 3939
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Title          3940 non-null   object
#  1   Year           3940 non-null   int64
#  2   Short Summary  3939 non-null   object
#  3   Genres         3940 non-null   object
#  4   Rating         3940 non-null   float64
#  5   Movie Poster   3940 non-null   object
#  6   Director       3940 non-null   object
#  7   Writers        3922 non-null   object
#  8   Cast           3916 non-null   object
# dtypes: float64(1), int64(1), object(7)
# memory usage: 277.2+ KB

# %%
# creating a very simple user interface
print("Welcome to Movie Hub")
print("Please enter the name of the movie")
name = input("Enter your movie name: ")

# Filter DataFrame based on user input
matching_movies = movies_df[movies_df["Title"].str.contains(name, case=False, na=False)]

if not matching_movies.empty:
    print("Matching Movies:")
    display(matching_movies)
else:
    print("Movie not found. Enter something else")
    year = input("Enter the year the movie was released in: ")
    
    # Convert year to integer
    try:
        year = int(year)
        matching_movies_by_year = movies_df[movies_df["Year"] == year]
        
        if not matching_movies_by_year.empty:
            print("Movies released in", year)
            display(matching_movies_by_year)
            #print(tabulate(matching_movies, headers='keys', tablefmt='grid'))
        else:
            print("No movies found for the entered year. See you again!")
            genres = input("Enter the genres of the movie")
            try:
                matching_movie_by_genres = movies_df[movies_df["Genres"].str.contains(genres, case=False, na=False)]
                if not matching_movie_by_genres.empty:
                    print("movies by genres")
                    display(matching_movie_by_genres)
                else:
                    print("NO movie with that generes")
            except ValueError:
                print("Invalid format. Please enter a genres.")

    except valueError:
        print("Thank for visiting")
# Out:
# Welcome to Movie Hub
# Please enter the name of the movie
# Enter your movie name:  inception
# Matching Movies:
#           Title  Year                                      Short Summary  \
# 2149  Inception  2010  A thief who steals corporate secrets through t...
#
#                                      Genres  Rating  \
# 2149  Action|Adventure|Crime|Mystery|Sci-Fi     8.8
#
#                                            Movie Poster           Director  \
# 2149  https://hydramovies.com/wp-content/uploads/201...  Christopher Nolan
#
#                 Writers                                               Cast
# 2149  Christopher Nolan  Ellen Page|Joseph Gordon-Levitt|Leonardo DiCaprio
